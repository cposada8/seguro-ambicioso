# %% [markdown]
# # Seguro - Ambicioso

# %% [markdown]
# -Añadir descripción del juego-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
# funciones auxiliares
def lanzar_dado(n=6):
    # Function to generate a random number between 1 and n
    # simulating a dice.
    resultado = random.randint(1,n)
    return resultado

def desea_lanzar(respuesta):
    # function that returns true if the user wants to roll a dice again
    
    respuesta = respuesta.lower()
    if respuesta in ["si", "sí", "yes", "true", "y", "s"]:
        return True
    else:
        return False

# %%
lanzar_dado()
# Out:
# 5

# %%
### Verificar función de lanzar dado
resultados = []
for i in range(10000):
    resultados.append(lanzar_dado())

# %%
plt.title("histograma de resultados")
plt.hist(resultados, density=True)
plt.xlabel("resultado dado")
plt.ylabel("frecuencia relativa")
plt.show()

# %%
class Agent:
    def __init__(self, name, max_tiros, max_score):
        self.name = name
        self.max_tiros = max_tiros
        self.max_score = max_score
        
    def __str__(self):
        cadena= f"""
        nombre: {self.name},
        max_tiros: {self.max_tiros},
        max_score: {self.max_score}
        """
        return cadena
        
    def desea_lanzar(self, lanzamientos, puntos_turno):
        if lanzamientos <= self.max_tiros and puntos_turno <= self.max_score:
            return True
        else:
            return False

a1 = Agent("a1", 60, 10)
a2 = Agent("a2", 5, 100)

# %%
def jugar_turno(agente, left_score):
    lanzar = True
    perdio = False
    lanzamientos = 0
    puntos_turno = 0
    resultados = []
    while(lanzar and not perdio):
        lanzamientos +=1
        
        resultado = lanzar_dado()
        resultados.append(resultado)
        puntos_turno += resultado

        if resultado == 1:
            puntos_turno = 0
            perdio = True
            
        #print(lanzamientos, resultado, puntos_turno )
        if puntos_turno>= left_score: # parar de lanzar pues ya se alcanzó el objetivo
            break
            
        if (not perdio):
            lanzar = agente.desea_lanzar(lanzamientos, puntos_turno)#desea_lanzar(input("¿desea lanzar de nuevo?"))
            
    return puntos_turno, lanzamientos, resultados

# %%
# jugar_turno(a1, 25)
# jugar_turno(a2, 100)

# %%
def jugar_partida(numero_partida, agente, target_score=100):
    turnos = 0
    acumulado = 0

    resultados_turnos = {}
    df_turnos = pd.DataFrame()

    while (acumulado < target_score):
        turnos+=1
        puntos_turno, lanzamientos, resultados = jugar_turno(agente, target_score-acumulado)
        acumulado += puntos_turno

        dict_turno = {
            'partida': numero_partida,
            'agente': agente,
            'agent_name': agente.name,
            'target': target_score,
            'turno': turnos,
            'lanzamientos': lanzamientos,
            'puntos_turno': puntos_turno,
            'resultados': [resultados],
            'acumulado': acumulado
        }
        df_turno = pd.DataFrame(dict_turno)
        df_turnos = df_turnos.append(df_turno)
    return df_turnos, turnos, acumulado

# %%
df_resultados, _, _=jugar_partida(1, a1)
df_resultados
# Out:
#    partida                                             agente agent_name  \
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
# 0        1  \n        nombre: a1,\n        max_tiros: 60,\...         a1
#
#    target  turno  lanzamientos  puntos_turno       resultados  acumulado
# 0     100      1             1             0              [1]          0
# 0     100      2             1             0              [1]          0
# 0     100      3             3            12        [2, 5, 5]         12
# 0     100      4             2            12           [6, 6]         24
# 0     100      5             1             0              [1]         24
# 0     100      6             2             0           [6, 1]         24
# 0     100      7             5            14  [3, 2, 2, 3, 4]         38
# 0     100      8             3            15        [6, 4, 5]         53
# 0     100      9             1             0              [1]         53
# 0     100     10             1             0              [1]         53
# 0     100     11             2            11           [6, 5]         64
# 0     100     12             3            11        [4, 2, 5]         75
# 0     100     13             3             0        [3, 5, 1]         75
# 0     100     14             2            11           [6, 5]         86
# 0     100     15             1             0              [1]         86
# 0     100     16             3            14        [3, 6, 5]        100

# %%
# Simular n partidas
def simular_n_partidas(agente, num_sim=100, verbose = 0):
    df_detalle = pd.DataFrame()
    for i in range(num_sim):
        if verbose!=0:
            if i%verbose==0:
                print("simulando caso ", i)

                
        df_resultados, turnos, acumulado = jugar_partida(i, agente)
        df_detalle = df_detalle.append(df_resultados)
    
    df_grouped = df_detalle.groupby("partida").agg({'turno':  'max', 
                                                  'lanzamientos': 'mean', 
                                                  'puntos_turno': 'mean',
                                                  'acumulado':'max'})
    return df_grouped, df_detalle

# %%
gruped, detalle = simular_n_partidas(a1, 10, 1)
# Out:
# simulando caso  0
# simulando caso  1
# simulando caso  2
# simulando caso  3
# simulando caso  4
# simulando caso  5
# simulando caso  6
# simulando caso  7
# simulando caso  8
# simulando caso  9

# %% [markdown]
# ## Generar los distintos agentes

# %%
# Primero comparemos 2 agentes a ver cuál estrategia es mejor

# %%
configs =[(3, 100),
(4, 100),
(5, 100),
(6, 100),
(7, 100),
(8, 100),
(9, 100),
(10, 100),
(11, 100),
(12, 100),
(13, 100),
(14, 100),
(15, 100),
(16, 100),
(17, 100),
(100, 2),
(100, 6),
(100, 10),
(100, 11),
(100, 12),
(100, 13),
(100, 14),
(100, 15),
(100, 16),
(100, 17),
(100, 18),
(100, 19),
(100, 20),
(100, 21),
(100, 22),
(100, 23),
(100, 24),
(100, 25),
(100, 26),
(100, 27),
(100, 28),
(100, 29),
(100, 30),
(100, 31),
(100, 32),
(100, 33),
(100, 34),
(100, 35),
(100, 36),
(100, 37),
(100, 38),
(100, 39),
(100, 40),
(100, 45),
(100, 50),
(100, 55),
(100, 60),
]

# %%
# Creación de agentes
agents = []
for config in configs:
    max_lanz_agent = config[0]
    max_score_agent = config[1]
    name_agent = f"{max_lanz_agent}-{max_score_agent}"
    agent = Agent(name_agent, max_lanz_agent, max_score_agent)
    agents.append(agent)

# %%
len(agents)
# Out:
# 52

# %%
agents_results = []
num_agents = len(agents)
for i, agent in enumerate(agents):
    print(f"{agent.name} - {i+1}/{num_agents}")
    g_agent, d_agent = simular_n_partidas(agent, 3)
    
    agent_res_dict = {
        "name": agent.name,
        "grouped_df": g_agent,
        "detalle_df": d_agent
    }
    
    agents_results.append(agent_res_dict)
# Out:
# 3-100 - 1/52
# 4-100 - 2/52
# 5-100 - 3/52
# 6-100 - 4/52
# 7-100 - 5/52
# 8-100 - 6/52
# 9-100 - 7/52
# 10-100 - 8/52
# 11-100 - 9/52
# 12-100 - 10/52
# 13-100 - 11/52
# 14-100 - 12/52
# 15-100 - 13/52
# 16-100 - 14/52
# 17-100 - 15/52
# 100-2 - 16/52
# 100-6 - 17/52
# 100-10 - 18/52
# 100-11 - 19/52
# 100-12 - 20/52
# 100-13 - 21/52
# 100-14 - 22/52
# 100-15 - 23/52
# 100-16 - 24/52
# 100-17 - 25/52
# 100-18 - 26/52
# 100-19 - 27/52
# 100-20 - 28/52
# 100-21 - 29/52
# 100-22 - 30/52
# 100-23 - 31/52
# 100-24 - 32/52
# 100-25 - 33/52
# 100-26 - 34/52
# 100-27 - 35/52
# 100-28 - 36/52
# 100-29 - 37/52
# 100-30 - 38/52
# 100-31 - 39/52
# 100-32 - 40/52
# 100-33 - 41/52
# 100-34 - 42/52
# 100-35 - 43/52
# 100-36 - 44/52
# 100-37 - 45/52
# 100-38 - 46/52
# 100-39 - 47/52
# 100-40 - 48/52
# 100-45 - 49/52
# 100-50 - 50/52
# 100-55 - 51/52
# 100-60 - 52/52

# %%
# agents_results

# %%
turnos_df = pd.DataFrame()
for result in agents_results:
    col_name = f"turnos_{result['name']}"
    print(col_name)
    turnos_df[col_name] = result['grouped_df']['turno']
# Out:
# turnos_3-100
# turnos_4-100
# turnos_5-100
# turnos_6-100
# turnos_7-100
# turnos_8-100
# turnos_9-100
# turnos_10-100
# turnos_11-100
# turnos_12-100
# turnos_13-100
# turnos_14-100
# turnos_15-100
# turnos_16-100
# turnos_17-100
# turnos_100-2
# turnos_100-6
# turnos_100-10
# turnos_100-11
# turnos_100-12
# turnos_100-13
# turnos_100-14
# turnos_100-15
# turnos_100-16
# turnos_100-17
# turnos_100-18
# turnos_100-19
# turnos_100-20
# turnos_100-21
# turnos_100-22
# turnos_100-23
# turnos_100-24
# turnos_100-25
# turnos_100-26
# turnos_100-27
# turnos_100-28
# turnos_100-29
# turnos_100-30
# turnos_100-31
# turnos_100-32
# turnos_100-33
# turnos_100-34
# turnos_100-35
# turnos_100-36
# turnos_100-37
# turnos_100-38
# turnos_100-39
# turnos_100-40
# turnos_100-45
# turnos_100-50
# turnos_100-55
# turnos_100-60

# %%
turnos_df.describe().T
# Out:
#                count       mean        std   min   25%   50%   75%   max
# turnos_3-100     3.0  18.000000   5.000000  13.0  15.5  18.0  20.5  23.0
# turnos_4-100     3.0  13.000000   2.000000  11.0  12.0  13.0  14.0  15.0
# turnos_5-100     3.0  12.666667   5.773503   6.0  11.0  16.0  16.0  16.0
# turnos_6-100     3.0  15.666667   2.886751  14.0  14.0  14.0  16.5  19.0
# turnos_7-100     3.0  13.666667   5.131601   8.0  11.5  15.0  16.5  18.0
# turnos_8-100     3.0   9.666667   1.527525   8.0   9.0  10.0  10.5  11.0
# turnos_9-100     3.0   8.333333   4.163332   5.0   6.0   7.0  10.0  13.0
# turnos_10-100    3.0  15.000000   4.582576  10.0  13.0  16.0  17.5  19.0
# turnos_11-100    3.0  13.333333   8.082904   6.0   9.0  12.0  17.0  22.0
# turnos_12-100    3.0  24.666667   8.962886  19.0  19.5  20.0  27.5  35.0
# turnos_13-100    3.0  27.666667  13.316656  19.0  20.0  21.0  32.0  43.0
# turnos_14-100    3.0  22.000000  18.083141   5.0  12.5  20.0  30.5  41.0
# turnos_15-100    3.0  17.333333  11.846237  10.0  10.5  11.0  21.0  31.0
# turnos_16-100    3.0  11.666667   9.073772   5.0   6.5   8.0  15.0  22.0
# turnos_17-100    3.0  18.333333  15.695010   6.0   9.5  13.0  24.5  36.0
# turnos_100-2     3.0  26.000000   1.000000  25.0  25.5  26.0  26.5  27.0
# turnos_100-6     3.0  16.666667   4.509250  12.0  14.5  17.0  19.0  21.0
# turnos_100-10    3.0  12.333333   2.516611  10.0  11.0  12.0  13.5  15.0
# turnos_100-11    3.0  13.333333   4.725816   8.0  11.5  15.0  16.0  17.0
# turnos_100-12    3.0  15.333333   5.131601  11.0  12.5  14.0  17.5  21.0
# turnos_100-13    3.0  13.333333   4.509250   9.0  11.0  13.0  15.5  18.0
# turnos_100-14    3.0  12.000000   1.000000  11.0  11.5  12.0  12.5  13.0
# turnos_100-15    3.0   9.000000   1.000000   8.0   8.5   9.0   9.5  10.0
# turnos_100-16    3.0  10.666667   0.577350  10.0  10.5  11.0  11.0  11.0
# turnos_100-17    3.0  12.666667   7.505553   5.0   9.0  13.0  16.5  20.0
# turnos_100-18    3.0  13.666667   0.577350  13.0  13.5  14.0  14.0  14.0
# turnos_100-19    3.0  11.333333   3.785939   7.0  10.0  13.0  13.5  14.0
# turnos_100-20    3.0  11.666667   3.055050   9.0  10.0  11.0  13.0  15.0
# turnos_100-21    3.0  13.666667   3.214550  10.0  12.5  15.0  15.5  16.0
# turnos_100-22    3.0  11.333333   5.859465   7.0   8.0   9.0  13.5  18.0
# turnos_100-23    3.0  19.000000   6.244998  12.0  16.5  21.0  22.5  24.0
# turnos_100-24    3.0  12.666667   5.033223   8.0  10.0  12.0  15.0  18.0
# turnos_100-25    3.0  25.333333   8.386497  20.0  20.5  21.0  28.0  35.0
# turnos_100-26    3.0  11.000000   2.000000   9.0  10.0  11.0  12.0  13.0
# turnos_100-27    3.0  14.666667  12.423097   7.0   7.5   8.0  18.5  29.0
# turnos_100-28    3.0  25.000000  18.681542   8.0  15.0  22.0  33.5  45.0
# turnos_100-29    3.0  10.666667   2.081666   9.0   9.5  10.0  11.5  13.0
# turnos_100-30    3.0  18.000000  13.892444   9.0  10.0  11.0  22.5  34.0
# turnos_100-31    3.0  15.000000   6.000000   9.0  12.0  15.0  18.0  21.0
# turnos_100-32    3.0  13.000000   3.464102  11.0  11.0  11.0  14.0  17.0
# turnos_100-33    3.0  12.333333   4.163332   9.0  10.0  11.0  14.0  17.0
# turnos_100-34    3.0  19.000000  11.000000   8.0  13.5  19.0  24.5  30.0
# turnos_100-35    3.0  35.666667  10.408330  24.0  31.5  39.0  41.5  44.0
# turnos_100-36    3.0  15.666667   5.033223  11.0  13.0  15.0  18.0  21.0
# turnos_100-37    3.0   8.666667   3.511885   5.0   7.0   9.0  10.5  12.0
# turnos_100-38    3.0   9.666667   4.509250   5.0   7.5  10.0  12.0  14.0
# turnos_100-39    3.0  20.666667  15.011107  12.0  12.0  12.0  25.0  38.0
# turnos_100-40    3.0  14.666667  10.263203   6.0   9.0  12.0  19.0  26.0
# turnos_100-45    3.0  24.666667  19.139836   9.0  14.0  19.0  32.5  46.0
# turnos_100-50    3.0  17.666667  15.885003   8.0   8.5   9.0  22.5  36.0
# turnos_100-55    3.0  23.666667  15.275252   7.0  17.0  27.0  32.0  37.0
# turnos_100-60    3.0   8.333333   4.509250   4.0   6.0   8.0  10.5  13.0

# %% [markdown]
# ### Agentes combinados

# %%
max_lanzs = [3, 4, 5, 6, 7]
max_scrs = [17, 18, 19, 20, 21, 22, 23]

# %%
agents = []
for ml in max_lanzs:
    for ms in max_scrs:
        print(ml, ms)
        name_agent = f"{ml}-{ms}"
        agent = Agent(name_agent, ml, ms)
        agents.append(agent)
# Out:
# 3 17
# 3 18
# 3 19
# 3 20
# 3 21
# 3 22
# 3 23
# 4 17
# 4 18
# 4 19
# 4 20
# 4 21
# 4 22
# 4 23
# 5 17
# 5 18
# 5 19
# 5 20
# 5 21
# 5 22
# 5 23
# 6 17
# 6 18
# 6 19
# 6 20
# 6 21
# 6 22
# 6 23
# 7 17
# 7 18
# 7 19
# 7 20
# 7 21
# 7 22
# 7 23

# %%
agents_results = []
num_agents = len(agents)
for i, agent in enumerate(agents):
    print(f"{agent.name} - {i+1}/{num_agents}")
    g_agent, d_agent = simular_n_partidas(agent, 3)
    
    agent_res_dict = {
        "name": agent.name,
        "grouped_df": g_agent,
        "detalle_df": d_agent
    }
    
    agents_results.append(agent_res_dict)
# Out:
# 3-17 - 1/35
# 3-18 - 2/35
# 3-19 - 3/35
# 3-20 - 4/35
# 3-21 - 5/35
# 3-22 - 6/35
# 3-23 - 7/35
# 4-17 - 8/35
# 4-18 - 9/35
# 4-19 - 10/35
# 4-20 - 11/35
# 4-21 - 12/35
# 4-22 - 13/35
# 4-23 - 14/35
# 5-17 - 15/35
# 5-18 - 16/35
# 5-19 - 17/35
# 5-20 - 18/35
# 5-21 - 19/35
# 5-22 - 20/35
# 5-23 - 21/35
# 6-17 - 22/35
# 6-18 - 23/35
# 6-19 - 24/35
# 6-20 - 25/35
# 6-21 - 26/35
# 6-22 - 27/35
# 6-23 - 28/35
# 7-17 - 29/35
# 7-18 - 30/35
# 7-19 - 31/35
# 7-20 - 32/35
# 7-21 - 33/35
# 7-22 - 34/35
# 7-23 - 35/35

# %%
turnos_df = pd.DataFrame()
for result in agents_results:
    col_name = f"turnos_{result['name']}"
    print(col_name)
    turnos_df[col_name] = result['grouped_df']['turno']
# Out:
# turnos_3-17
# turnos_3-18
# turnos_3-19
# turnos_3-20
# turnos_3-21
# turnos_3-22
# turnos_3-23
# turnos_4-17
# turnos_4-18
# turnos_4-19
# turnos_4-20
# turnos_4-21
# turnos_4-22
# turnos_4-23
# turnos_5-17
# turnos_5-18
# turnos_5-19
# turnos_5-20
# turnos_5-21
# turnos_5-22
# turnos_5-23
# turnos_6-17
# turnos_6-18
# turnos_6-19
# turnos_6-20
# turnos_6-21
# turnos_6-22
# turnos_6-23
# turnos_7-17
# turnos_7-18
# turnos_7-19
# turnos_7-20
# turnos_7-21
# turnos_7-22
# turnos_7-23

# %%
turnos_df.describe().T.sort_values([ "std","50%","mean"])
# Out:
#              count       mean       std   min   25%   50%   75%   max
# turnos_6-22    3.0  13.000000  1.000000  12.0  12.5  13.0  13.5  14.0
# turnos_7-22    3.0  10.333333  1.154701   9.0  10.0  11.0  11.0  11.0
# turnos_4-20    3.0  13.666667  1.154701  13.0  13.0  13.0  14.0  15.0
# turnos_3-17    3.0  11.333333  1.527525  10.0  10.5  11.0  12.0  13.0
# turnos_4-18    3.0  11.666667  1.527525  10.0  11.0  12.0  12.5  13.0
# turnos_5-17    3.0  12.000000  1.732051  10.0  11.5  13.0  13.0  13.0
# turnos_5-23    3.0  10.000000  2.000000   8.0   9.0  10.0  11.0  12.0
# turnos_5-19    3.0  15.000000  2.000000  13.0  14.0  15.0  16.0  17.0
# turnos_6-18    3.0   9.666667  2.081666   8.0   8.5   9.0  10.5  12.0
# turnos_3-21    3.0   9.333333  2.309401   8.0   8.0   8.0  10.0  12.0
# turnos_3-19    3.0   9.333333  2.516611   7.0   8.0   9.0  10.5  12.0
# turnos_5-21    3.0  12.333333  2.516611  10.0  11.0  12.0  13.5  15.0
# turnos_4-22    3.0  13.000000  3.000000  10.0  11.5  13.0  14.5  16.0
# turnos_3-23    3.0  12.333333  3.055050   9.0  11.0  13.0  14.0  15.0
# turnos_3-22    3.0  17.000000  3.464102  15.0  15.0  15.0  18.0  21.0
# turnos_7-17    3.0  14.333333  3.511885  11.0  12.5  14.0  16.0  18.0
# turnos_3-18    3.0  12.666667  3.785939  10.0  10.5  11.0  14.0  17.0
# turnos_3-20    3.0  14.666667  3.785939  12.0  12.5  13.0  16.0  19.0
# turnos_7-21    3.0  16.000000  4.000000  12.0  14.0  16.0  18.0  20.0
# turnos_5-20    3.0  13.666667  4.041452   9.0  12.5  16.0  16.0  16.0
# turnos_6-21    3.0  18.333333  4.041452  14.0  16.5  19.0  20.5  22.0
# turnos_5-18    3.0  13.000000  4.358899  10.0  10.5  11.0  14.5  18.0
# turnos_4-21    3.0  11.333333  4.725816   6.0   9.5  13.0  14.0  15.0
# turnos_4-23    3.0  16.666667  4.725816  13.0  14.0  15.0  18.5  22.0
# turnos_4-19    3.0  15.666667  4.932883  10.0  14.0  18.0  18.5  19.0
# turnos_5-22    3.0  12.000000  5.291503   8.0   9.0  10.0  14.0  18.0
# turnos_4-17    3.0  13.333333  5.507571   7.0  11.5  16.0  16.5  17.0
# turnos_7-18    3.0  11.000000  6.000000   5.0   8.0  11.0  14.0  17.0
# turnos_6-20    3.0  18.000000  6.082763  11.0  16.0  21.0  21.5  22.0
# turnos_7-23    3.0  15.333333  6.110101  10.0  12.0  14.0  18.0  22.0
# turnos_6-23    3.0  16.333333  6.429101   9.0  14.0  19.0  20.0  21.0
# turnos_6-17    3.0  13.000000  7.000000   8.0   9.0  10.0  15.5  21.0
# turnos_7-19    3.0  15.000000  7.937254   9.0  10.5  12.0  18.0  24.0
# turnos_6-19    3.0  15.666667  8.082904  11.0  11.0  11.0  18.0  25.0
# turnos_7-20    3.0  14.666667  8.144528   9.0  10.0  11.0  17.5  24.0

# %%
sns.distplot(turnos_df['turnos_7-23'], label='turnos_7-23')
sns.distplot(turnos_df['turnos_3-18'], label='turnos_3-18')
sns.distplot(turnos_df['turnos_4-22'], label = 'turnos_4-22')
plt.legend()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
turnos_df
# Out:
#          turnos_3-17  turnos_3-18  turnos_3-19  turnos_3-20  turnos_3-21  \
# partida
# 0                 11           11            9           12           12
# 1                 10           17           12           13            8
# 2                 13           10            7           19            8
#
#          turnos_3-22  turnos_3-23  turnos_4-17  turnos_4-18  turnos_4-19  ...  \
# partida                                                                   ...
# 0                 15            9           17           10           18  ...
# 1                 21           15           16           12           10  ...
# 2                 15           13            7           13           19  ...
#
#          turnos_6-21  turnos_6-22  turnos_6-23  turnos_7-17  turnos_7-18  \
# partida
# 0                 19           12           19           18            5
# 1                 14           14           21           11           17
# 2                 22           13            9           14           11
#
#          turnos_7-19  turnos_7-20  turnos_7-21  turnos_7-22  turnos_7-23
# partida
# 0                 12            9           12           11           10
# 1                  9           24           16            9           22
# 2                 24           11           20           11           14
#
# [3 rows x 35 columns]
